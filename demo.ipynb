# %%
import dmpchef
import os
import json
from pathlib import Path

# Input JSON path
input_path = Path("data") / "inputs" / "input.json"
with input_path.open("r", encoding="utf-8") as f:
    data = json.load(f)

print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "config": {
#     "funding": {
#       "agency": "NIH",
#       "subagency": "NIMH"
#     },
#     "pipeline": {
#       "rag": true,
#       "llm": {
#         "provider": "ollama",
#         "model_name": "llama3.3:latest"
#       }
#     },
#     "export": {
#       "md": true,
#       "docx": true,
#       "pdf": true,
#       "dmptool_json": true
#     }
#   },
#   "inputs": {
#     "research_area": "Autism and social communication",
#     "research_context": "This study examines social communication and neurodevelopmental profiles in youth with autism compared to typically developing peers using behavioral, clinical, and neurobiological measures. NDA GUID elements will be collected for submission to the NIMH Data Archive (NDA).",
#     "data_types": "Demographic and clinical datasets; behavioral and cognitive assessments; neuroimaging and/or physiological measures; derived variables; documentation (protocols, data dictionary, README).",
#     "data_source": "IRB-approved human participant study using standardized assessments and research data capture systems.",
#     "human_subjects": "Yes",
#     "consent_status": "Broad data sharing consent/assent obtained as appropriate.",
#     "data_volume": "Multi-modal datasets from youth participants; neurobiological data represent the largest portion of storage."
#   }
# }

# %%
# ----------------------------
# Run No-RAG 
# ----------------------------
from dmpchef.api import generate

# No-RAG:
result = generate(input_path, use_rag=False)

# Show export file paths only
print("\n Export files:")
for name, path in result["outputs"].items():
    print(f"{name}: {path}")
# Out:
# {"timestamp": "2026-02-12T18:42:06.058999Z", "level": "info", "event": "Config loaded successfully"}
# {"llm": "llama3.3:latest", "embed": "sentence-transformers/all-MiniLM-L6-v2", "hf_cache_dir": "data/cache/hf", "local_files_only": true, "allow_download_if_missing": true, "temperature": null, "num_predict": null, "num_ctx": null, "top_p": null, "top_k": null, "timestamp": "2026-02-12T18:42:06.061001Z", "level": "info", "event": "ModelLoader initialized"}
# {"llm": "llama3.3:latest", "rag_default": true, "data_pdfs": "data\\database", "index_dir": "data\\index", "debug_dir": "data\\outputs\\debug", "force_rebuild_index": false, "timestamp": "2026-02-12T18:42:06.069997Z", "level": "info", "event": "DMPPipeline initialized"}
# {"funding_agency": "NIH", "prompt_type": "nih_dmp", "template_md": "data\\inputs\\dmp-template.md", "retrieval_hint": "NIH Data Management and Sharing Plan (DMSP) guidance", "timestamp": "2026-02-12T18:42:06.071001Z", "level": "info", "event": "Funding agency selected"}
# {"mode": "norag", "use_rag_input": false, "rag_default": true, "use_rag_final": false, "timestamp": "2026-02-12T18:42:06.071998Z", "level": "info", "event": "Pipeline mode selected"}
# {"title_present": true, "title": "req_8f03ec1fc5", "input_fields": 9, "timestamp": "2026-02-12T18:42:06.071998Z", "level": "info", "event": "Inputs parsed"}
# {"run_stem": "req_8f03ec1fc5__norag__llama3.3_latest", "base_stem": "req_8f03ec1fc5", "mode": "norag", "top_k": 6, "llm": "llama3.3:latest", "timestamp": "2026-02-12T18:42:06.072998Z", "level": "info", "event": "Run naming"}
# {"question_chars": 4941, "template_chars": 3863, "user_elements_lines": 9, "timestamp": "2026-02-12T18:42:06.072998Z", "level": "info", "event": "Prompt scaffold ready"}
# {"mode": "norag", "prompt_chars": 5989, "timestamp": "2026-02-12T18:42:06.073999Z", "level": "info", "event": "LLM start"}
# HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# {"mode": "norag", "timestamp": "2026-02-12T18:43:04.681419Z", "level": "info", "event": "LLM done"}
# {"mode": "norag", "output_chars": 6079, "timestamp": "2026-02-12T18:43:04.682419Z", "level": "info", "event": "DMP generation finished"}
# 100%|██████████| 1/1 [00:02<00:00,  2.85s/it]
#  Export files:
# markdown: C:\Users\Nahid\dmpchef\data\outputs\markdown\req_8f03ec1fc5__104304__norag__llama3.3_latest.md
# dmptool_json: C:\Users\Nahid\dmpchef\data\outputs\json\req_8f03ec1fc5__104304__norag__llama3.3_latest.dmptool.json
# docx: C:\Users\Nahid\dmpchef\data\outputs\docx\req_8f03ec1fc5__104304__norag__llama3.3_latest.docx
# pdf: C:\Users\Nahid\dmpchef\data\outputs\pdf\req_8f03ec1fc5__104304__norag__llama3.3_latest.pdf

# %%
# ----------------------------
# Run RAG 
# ----------------------------
from dmpchef.api import generate

# RAG:
result = generate(input_path, use_rag=True)

# Show export file paths only
print("\n Export files:")
for name, path in result["outputs"].items():
    print(f"{name}: {path}")
# Out:
# {"timestamp": "2026-02-12T18:43:08.347932Z", "level": "info", "event": "Config loaded successfully"}
# {"llm": "llama3.3:latest", "embed": "sentence-transformers/all-MiniLM-L6-v2", "hf_cache_dir": "data/cache/hf", "local_files_only": true, "allow_download_if_missing": true, "temperature": null, "num_predict": null, "num_ctx": null, "top_p": null, "top_k": null, "timestamp": "2026-02-12T18:43:08.349931Z", "level": "info", "event": "ModelLoader initialized"}
# {"llm": "llama3.3:latest", "rag_default": true, "data_pdfs": "data\\database", "index_dir": "data\\index", "debug_dir": "data\\outputs\\debug", "force_rebuild_index": false, "timestamp": "2026-02-12T18:43:08.357935Z", "level": "info", "event": "DMPPipeline initialized"}
# {"funding_agency": "NIH", "prompt_type": "nih_dmp", "template_md": "data\\inputs\\dmp-template.md", "retrieval_hint": "NIH Data Management and Sharing Plan (DMSP) guidance", "timestamp": "2026-02-12T18:43:08.359934Z", "level": "info", "event": "Funding agency selected"}
# {"mode": "rag", "use_rag_input": true, "rag_default": true, "use_rag_final": true, "timestamp": "2026-02-12T18:43:08.359934Z", "level": "info", "event": "Pipeline mode selected"}
# {"title_present": true, "title": "req_8f03ec1fc5", "input_fields": 9, "timestamp": "2026-02-12T18:43:08.360939Z", "level": "info", "event": "Inputs parsed"}
# {"run_stem": "req_8f03ec1fc5__rag__k6__llama3.3_latest", "base_stem": "req_8f03ec1fc5", "mode": "rag", "top_k": 6, "llm": "llama3.3:latest", "timestamp": "2026-02-12T18:43:08.360939Z", "level": "info", "event": "Run naming"}
# {"question_chars": 5103, "template_chars": 3863, "user_elements_lines": 9, "timestamp": "2026-02-12T18:43:08.360939Z", "level": "info", "event": "Prompt scaffold ready"}
# {"step": "ensure_rag_ready", "timestamp": "2026-02-12T18:43:08.360939Z", "level": "info", "event": "RAG phase start"}
# {"llm": "llama3.3:latest", "timestamp": "2026-02-12T18:43:08.361935Z", "level": "info", "event": "Loading embeddings for RAG"}
# c:\Users\Nahid\dmpchef\utils\model_loader.py:122: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   return HuggingFaceEmbeddings(
# Use pytorch device_name: cpu
# Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1572.26it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# {"model": "sentence-transformers/all-MiniLM-L6-v2", "cache_dir": "C:\\Users\\Nahid\\dmpchef\\data\\cache\\hf", "local_files_only": true, "timestamp": "2026-02-12T18:43:08.517947Z", "level": "info", "event": "Embeddings loaded successfully"}
# {"timestamp": "2026-02-12T18:43:08.518947Z", "level": "info", "event": "Embeddings ready"}
# {"index_dir": "data\\index", "force_rebuild": false, "timestamp": "2026-02-12T18:43:08.518947Z", "level": "info", "event": "Preparing FAISS vectorstore"}
# {"path": "data\\index\\index.faiss", "timestamp": "2026-02-12T18:43:08.518947Z", "level": "info", "event": "Loading existing FAISS index"}
# Loading faiss with AVX512 support.
# Could not load library with AVX512 support due to:
# ModuleNotFoundError("No module named 'faiss.swigfaiss_avx512'")
# Loading faiss with AVX2 support.
# Successfully loaded faiss with AVX2 support.
# {"search_type": "mmr", "top_k": 6, "fetch_k": 24, "lambda_mult": 0.5, "timestamp": "2026-02-12T18:43:08.542947Z", "level": "info", "event": "RAG retriever initialized"}
# {"step": "ensure_rag_ready", "timestamp": "2026-02-12T18:43:08.543950Z", "level": "info", "event": "RAG phase ready"}
# {"query_chars": 1038, "top_k": 6, "timestamp": "2026-02-12T18:43:08.543950Z", "level": "info", "event": "Retrieval start"}
# {"retrieved_docs": 6, "timestamp": "2026-02-12T18:43:08.577456Z", "level": "info", "event": "Retrieval raw done"}
# {"strategy": "first_fit", "selected_docs": 6, "approx_selected_chars": 5150, "max_ctx_chars": 12000, "timestamp": "2026-02-12T18:43:08.578456Z", "level": "info", "event": "Chunk selection"}
# {"retriever_top_k": 6, "retrieved_docs": 6, "retrieved_chars": 5472, "max_ctx_chars": 12000, "debug_context_file": "data\\outputs\\debug\\req_8f03ec1fc5__rag__k6__llama3.3_latest.retrieved_context.txt", "timestamp": "2026-02-12T18:43:08.580461Z", "level": "info", "event": "Retrieval complete"}
# {"mode": "rag", "prompt_chars": 11623, "timestamp": "2026-02-12T18:43:08.580461Z", "level": "info", "event": "LLM start"}
# HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# {"mode": "rag", "timestamp": "2026-02-12T18:44:02.485564Z", "level": "info", "event": "LLM done"}
# {"mode": "rag", "output_chars": 5255, "timestamp": "2026-02-12T18:44:02.485564Z", "level": "info", "event": "DMP generation finished"}
# 100%|██████████| 1/1 [00:02<00:00,  2.85s/it]
#  Export files:
# markdown: C:\Users\Nahid\dmpchef\data\outputs\markdown\req_8f03ec1fc5__104402__rag__k6__llama3.3_latest.md
# dmptool_json: C:\Users\Nahid\dmpchef\data\outputs\json\req_8f03ec1fc5__104402__rag__k6__llama3.3_latest.dmptool.json
# docx: C:\Users\Nahid\dmpchef\data\outputs\docx\req_8f03ec1fc5__104402__rag__k6__llama3.3_latest.docx
# pdf: C:\Users\Nahid\dmpchef\data\outputs\pdf\req_8f03ec1fc5__104402__rag__k6__llama3.3_latest.pdf

# %%
output_path = Path("data") / "outputs" /"json"/"req_8f03ec1fc5__104304__norag__llama3.3_latest.dmptool.json"
with output_path.open("r", encoding="utf-8") as f:
    data = json.load(f)

print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "dmptool": {
#     "provenance": "dmpchef",
#     "narrative": {
#       "title": "NIH Data Management and Sharing Plan",
#       "section": [
#         {
#           "order": 1,
#           "title": "Element 1: Data Type",
#           "description": "",
#           "question": [
#             {
#               "order": 1,
#               "text": "Types and amount of scientific data expected to be generated in the project",
#               "answer": {
#                 "json": {
#                   "answer": "The project 'req_8f03ec1fc5' aims to examine social communication and neurodevelopmental profiles in youth with autism compared to typically developing peers. The types of scientific data expected to be generated include demographic and clinical datasets, behavioral and cognitive assessments, neuroimaging and/or physiological measures, derived variables, and documentation such as protocols, data dictionary, and README files. The estimated amount of data is substantial, given the multi-modal nature of the datasets from youth participants, with neurobiological data representing the largest portion of storage.",
#                   "type": "textArea"
#                 }
#               }
#             },
#             {
#               "order": 2,
#               "text": "Scientific data that will be preserved and shared, and the rationale for doing so",
#               "answer": {
#                 "json": {
#                   "answer": "All scientific data generated from this project will be preserved and shared through the NIMH Data Archive (NDA), including demographic and clinical datasets, behavioral and cognitive assessments, neuroimaging, physiological measures, derived variables, and associated documentation. The rationale for sharing these data is to facilitate research on autism and social communication, enabling other researchers to validate findings, explore new hypotheses, and contribute to the development of more effective interventions.",
#                   "type": "textArea"
#                 }
#               }
#             },
#             {
#               "order": 3,
#               "text": "Metadata, other relevant data, and associated documentation",
#               "answer": {
#                 "json": {
#                   "answer": "To facilitate the interpretation of the scientific data, the following metadata, other relevant data, and associated documentation will be made accessible: study protocols, data collection instruments, data dictionaries explaining variable names and definitions, README files detailing data processing and analysis steps, and any other information necessary for understanding and replicating the research findings.",
#                   "type": "textArea"
#                 }
#               }
#             }
#           ]
#         },
#         {
#           "order": 2,
#           "title": "Element 2: Related Tools, Software and/or Code",
#           "description": "",
#           "question": [
#             {
#               "order": 1,
#               "text": "Element 2: Related Tools, Software and/or Code",
#               "answer": {
#                 "json": {
#                   "answer": "Specialized tools, software, and/or code are needed to access or manipulate shared scientific data. Specifically, neuroimaging data will require software such as FSL (FMRIB Software Library) or AFNI for analysis, while statistical analyses of behavioral and cognitive data may utilize R or Python with libraries like pandas and NumPy. These tools and software can be accessed through their respective websites or repositories.",
#                   "type": "textArea"
#                 }
#               }
#             }
#           ]
#         },
#         {
#           "order": 3,
#           "title": "Element 3: Standards",
#           "description": "",
#           "question": [
#             {
#               "order": 1,
#               "text": "Element 3: Standards",
#               "answer": {
#                 "json": {
#                   "answer": "To enable interoperability of datasets and resources, common data standards will be applied to the scientific data and associated metadata. For demographic and clinical datasets, standards from the National Institutes of Health (NIH) Data Dictionary and the PhenX Toolkit will be used. Neuroimaging data will adhere to the BIDS (Brain Imaging Data Structure) standard for organization and description. Behavioral and cognitive assessments will follow standards set by their respective measurement tools. If applicable, data will also comply with the FAIR principles (Findable, Accessible, Interoperable, Reusable).",
#                   "type": "textArea"
#                 }
#               }
#             }
#           ]
#         },
#         {
#           "order": 4,
#           "title": "Element 4: Data Preservation, Access, and Associated Timelines",
#           "description": "",
#           "question": [
#             {
#               "order": 1,
#               "text": "Repository where scientific data and metadata will be archived",
#               "answer": {
#                 "json": {
#                   "answer": "The scientific data and metadata arising from this project will be archived in the NIMH Data Archive (NDA), a repository that supports the sharing and reuse of data related to mental health research.",
#                   "type": "textArea"
#                 }
#               }
#             },
#             {
#               "order": 2,
#               "text": "How scientific data will be findable and identifiable",
#               "answer": {
#                 "json": {
#                   "answer": "The scientific data will be made findable and identifiable through the assignment of a persistent unique identifier, such as a DOI (Digital Object Identifier) for datasets, and through standard indexing tools available in the NDA repository. This ensures that the data can be easily located and accessed by other researchers.",
#                   "type": "textArea"
#                 }
#               }
#             },
#             {
#               "order": 3,
#               "text": "When and how long the scientific data will be made available",
#               "answer": {
#                 "json": {
#                   "answer": "The scientific data will be made available to other users no later than the time of an associated publication or the end of the performance period, whichever comes first. The data will remain available indefinitely through the NDA repository, subject to any limitations imposed by consent agreements or privacy protections.",
#                   "type": "textArea"
#                 }
#               }
#             }
#           ]
#         },
#         {
#           "order": 5,
#           "title": "Element 5: Access, Distribution, or Reuse Considerations",
#           "description": "",
#           "question": [
#             {
#               "order": 1,
#               "text": "Factors affecting subsequent access, distribution, or reuse of scientific data",
#               "answer": {
#                 "json": {
#                   "answer": "Factors that may affect subsequent access, distribution, or reuse of the scientific data include informed consent restrictions and the need for privacy and confidentiality protections. Given that broad data sharing consent/assent has been obtained as appropriate, data will be shared in a manner that maximizes accessibility while respecting these limitations.",
#                   "type": "textArea"
#                 }
#               }
#             },
#             {
#               "order": 2,
#               "text": "Whether access to scientific data will be controlled",
#               "answer": {
#                 "json": {
#                   "answer": "Access to certain parts of the scientific data may be controlled due to privacy concerns or restrictions imposed by informed consent documents. In such cases, access will be managed through the NDA's controlled access procedures, requiring approval for access to sensitive data.",
#                   "type": "textArea"
#                 }
#               }
#             },
#             {
#               "order": 3,
#               "text": "Protections for privacy, rights, and confidentiality of human research participants",
#               "answer": {
#                 "json": {
#                   "answer": "To protect the privacy, rights, and confidentiality of human research participants, all shared data will undergo de-identification processes as necessary. The use of Certificates of Confidentiality, where applicable, will further safeguard against disclosure of identifiable information. Data sharing agreements will also include terms that require recipients to adhere to strict confidentiality and privacy standards.",
#                   "type": "textArea"
#                 }
#               }
#             }
#           ]
#         },
#         {
#           "order": 6,
#           "title": "Element 6: Oversight of Data Management and Sharing",
#           "description": "",
#           "question": [
#             {
#               "order": 1,
#               "text": "Element 6: Oversight of Data Management and Sharing",
#               "answer": {
#                 "json": {
#                   "answer": "Compliance with this Data Management and Sharing Plan will be monitored and managed by the project's Principal Investigator (PI), in collaboration with the institution's research data management office. Regular oversight meetings will occur quarterly, or as needed, to review data sharing progress, address any issues related to data access or confidentiality, and ensure that all shared data adhere to the standards and timelines outlined in this plan. The PI and designated data managers will be responsible for ensuring that all project personnel understand their roles and responsibilities in implementing the Plan.",
#                   "type": "textArea"
#                 }
#               }
#             }
#           ]
#         }
#       ]
#     }
#   }
# }

# %%
output_path = Path("data") / "outputs" /"json"/"req_8f03ec1fc5__104402__rag__k6__llama3.3_latest.dmptool.json"
with output_path.open("r", encoding="utf-8") as f:
    data = json.load(f)

print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "dmptool": {
#     "provenance": "dmpchef",
#     "narrative": {
#       "title": "NIH Data Management and Sharing Plan",
#       "section": [
#         {
#           "order": 1,
#           "title": "Element 1: Data Type",
#           "description": "",
#           "question": [
#             {
#               "order": 1,
#               "text": "Types and amount of scientific data expected to be generated in the project",
#               "answer": {
#                 "json": {
#                   "answer": "This study on autism and social communication will generate multi-modal datasets from youth participants, including demographic and clinical datasets, behavioral and cognitive assessments, neuroimaging and/or physiological measures, derived variables, and associated documentation. The estimated volume of data is substantial, with neurobiological data representing the largest portion of storage.",
#                   "type": "textArea"
#                 }
#               }
#             },
#             {
#               "order": 2,
#               "text": "Scientific data that will be preserved and shared, and the rationale for doing so",
#               "answer": {
#                 "json": {
#                   "answer": "All collected data types will be preserved and shared to facilitate secondary research use, promote transparency, and enhance reproducibility. This decision aligns with NIH's commitment to maximizing the sharing of scientific data while protecting participant privacy and confidentiality. Broad data sharing consent/assent has been obtained from participants as appropriate.",
#                   "type": "textArea"
#                 }
#               }
#             },
#             {
#               "order": 3,
#               "text": "Metadata, other relevant data, and associated documentation",
#               "answer": {
#                 "json": {
#                   "answer": "To facilitate interpretation of the scientific data, the following will be made accessible: \nA comprehensive data dictionary defining all variables\nStudy protocols outlining data collection procedures\nData collection instruments used in the research\nREADME files providing context for each dataset",
#                   "type": "textArea"
#                 }
#               }
#             }
#           ]
#         },
#         {
#           "order": 2,
#           "title": "Element 2: Related Tools, Software and/or Code",
#           "description": "",
#           "question": [
#             {
#               "order": 1,
#               "text": "Element 2: Related Tools, Software and/or Code",
#               "answer": {
#                 "json": {
#                   "answer": "Specialized tools and software are needed to access or manipulate shared scientific data. Specifically:\nFor neuroimaging data, FMRIB Software Library (FSL) and FreeSurfer will be utilized.\nFor statistical analyses, R programming language with relevant packages will be employed.\nThese tools can be accessed through their respective official websites, ensuring that other researchers can use them to analyze and build upon the shared data.",
#                   "type": "textArea"
#                 }
#               }
#             }
#           ]
#         },
#         {
#           "order": 3,
#           "title": "Element 3: Standards",
#           "description": "",
#           "question": [
#             {
#               "order": 1,
#               "text": "Element 3: Standards",
#               "answer": {
#                 "json": {
#                   "answer": "To enable interoperability of datasets and resources, common data standards will be applied. The project will adhere to the National Institute of Mental Health Data Archive (NDA) guidelines for data submission, incorporating NDA GUID elements into the dataset structure. Additionally, data dictionaries will follow standardized formats to ensure clarity and consistency across different datasets.",
#                   "type": "textArea"
#                 }
#               }
#             }
#           ]
#         },
#         {
#           "order": 4,
#           "title": "Element 4: Data Preservation, Access, and Associated Timelines",
#           "description": "",
#           "question": [
#             {
#               "order": 1,
#               "text": "Repository where scientific data and metadata will be archived",
#               "answer": {
#                 "json": {
#                   "answer": "The scientific data and metadata arising from this project will be archived in the National Institute of Mental Health Data Archive (NDA), a repository designated by NIH for storing and sharing research data related to mental health studies.",
#                   "type": "textArea"
#                 }
#               }
#             },
#             {
#               "order": 2,
#               "text": "How scientific data will be findable and identifiable",
#               "answer": {
#                 "json": {
#                   "answer": "Each dataset will be assigned a persistent unique identifier, ensuring that it can be easily located and accessed. Standard indexing tools compatible with the NDA's data discovery interface will also be utilized to enhance findability.",
#                   "type": "textArea"
#                 }
#               }
#             },
#             {
#               "order": 3,
#               "text": "When and how long the scientific data will be made available",
#               "answer": {
#                 "json": {
#                   "answer": "The scientific data will be made available no later than the time of publication of the main findings or the end of the performance period, whichever comes first. Data will remain accessible for a minimum of 10 years after the project's completion to allow for extensive secondary analysis and replication studies.",
#                   "type": "textArea"
#                 }
#               }
#             }
#           ]
#         },
#         {
#           "order": 5,
#           "title": "Element 5: Access, Distribution, or Reuse Considerations",
#           "description": "",
#           "question": [
#             {
#               "order": 1,
#               "text": "Factors affecting subsequent access, distribution, or reuse of scientific data",
#               "answer": {
#                 "json": {
#                   "answer": "While maximizing data sharing is a priority, certain limitations apply due to the need to protect participant privacy and confidentiality. Data will be de-identified before sharing, and access may require approval from the NDA to ensure that data use aligns with the consent provided by participants.",
#                   "type": "textArea"
#                 }
#               }
#             },
#             {
#               "order": 2,
#               "text": "Whether access to scientific data will be controlled",
#               "answer": {
#                 "json": {
#                   "answer": "Yes, access to the scientific data will be controlled through the NIMH Data Archive (NDA). Researchers seeking to access the data must apply through the NDA's mechanisms, which include obtaining approval based on their intended use of the data and adherence to terms of use that protect participant confidentiality.",
#                   "type": "textArea"
#                 }
#               }
#             },
#             {
#               "order": 3,
#               "text": "Protections for privacy, rights, and confidentiality of human research participants",
#               "answer": {
#                 "json": {
#                   "answer": "To protect the privacy, rights, and confidentiality of human research participants:\nAll shared data will be thoroughly de-identified.\nCertificates of Confidentiality will be obtained where applicable to further safeguard against disclosure.\nResearchers accessing the data must agree to terms of use that include respecting participant confidentiality.",
#                   "type": "textArea"
#                 }
#               }
#             }
#           ]
#         },
#         {
#           "order": 6,
#           "title": "Element 6: Oversight of Data Management and Sharing",
#           "description": "",
#           "question": [
#             {
#               "order": 1,
#               "text": "Element 6: Oversight of Data Management and Sharing",
#               "answer": {
#                 "json": {
#                   "answer": "Compliance with this Data Management and Sharing Plan will be monitored and managed by the Principal Investigators (PIs), in collaboration with the institutional review board (IRB) and other relevant bodies at our institution. The PIs are responsible for ensuring that data management practices adhere to the plan, including timely submission of data to the designated repository, maintenance of documentation, and oversight of access requests. Regular reviews will be conducted annually or upon significant project milestones to ensure ongoing compliance with NIH policies and the terms outlined in this plan.",
#                   "type": "textArea"
#                 }
#               }
#             }
#           ]
#         }
#       ]
#     }
#   }
# }
