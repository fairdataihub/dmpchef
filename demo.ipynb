# %%
import dmpchef
import os
import json
from pathlib import Path

# Input JSON path
input_path = Path("data") / "inputs" / "input.json"
with input_path.open("r", encoding="utf-8") as f:
    data = json.load(f)

print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# {
#   "config": {
#     "funding": {
#       "agency": "NIH",
#       "subagency": "NIMH"
#     },
#     "pipeline": {
#       "rag": true,
#       "llm": {
#         "provider": "ollama",
#         "model_name": "llama3.3:latest"
#       }
#     },
#     "export": {
#       "md": true,
#       "docx": true,
#       "pdf": true,
#       "dmptool_json": true
#     }
#   },
#   "inputs": {
#     "research_area": "Autism and social communication",
#     "research_context": "This study examines social communication and neurodevelopmental profiles in youth with autism compared to typically developing peers using behavioral, clinical, and neurobiological measures. NDA GUID elements will be collected for submission to the NIMH Data Archive (NDA).",
#     "data_types": "Demographic and clinical datasets; behavioral and cognitive assessments; neuroimaging and/or physiological measures; derived variables; documentation (protocols, data dictionary, README).",
#     "data_source": "IRB-approved human participant study using standardized assessments and research data capture systems.",
#     "human_subjects": "Yes",
#     "consent_status": "Broad data sharing consent/assent obtained as appropriate.",
#     "data_volume": "Multi-modal datasets from youth participants; neurobiological data represent the largest portion of storage."
#   }
# }

# %%
# ----------------------------
# Run No-RAG 
# ----------------------------
from dmpchef.api import generate

# No-RAG:
result = generate(input_path, use_rag=False)

# Show export file paths only
print("\n Export files:")
for name, path in result["outputs"].items():
    print(f"{name}: {path}")
# Out:
# {"timestamp": "2026-02-13T16:12:25.650475Z", "level": "info", "event": "Config loaded successfully"}
# {"llm": "llama3.3:latest", "embed": "sentence-transformers/all-MiniLM-L6-v2", "hf_cache_dir": "data/cache/hf", "local_files_only": true, "allow_download_if_missing": true, "temperature": null, "num_predict": null, "num_ctx": null, "top_p": null, "top_k": null, "timestamp": "2026-02-13T16:12:25.652476Z", "level": "info", "event": "ModelLoader initialized"}
# {"llm": "llama3.3:latest", "rag_default": true, "data_pdfs": "data\\database", "index_dir": "data\\index", "debug_dir": "data\\outputs\\debug", "force_rebuild_index": false, "timestamp": "2026-02-13T16:12:25.663989Z", "level": "info", "event": "DMPPipeline initialized"}
# {"funding_agency": "NIH", "prompt_type": "nih_dmp", "template_md": "data\\inputs\\dmp-template.md", "retrieval_hint": "NIH Data Management and Sharing Plan (DMSP) guidance", "timestamp": "2026-02-13T16:12:25.664988Z", "level": "info", "event": "Funding agency selected"}
# {"mode": "norag", "use_rag_input": false, "rag_default": true, "use_rag_final": false, "timestamp": "2026-02-13T16:12:25.665989Z", "level": "info", "event": "Pipeline mode selected"}
# {"title_present": true, "title": "req_8f03ec1fc5", "input_fields": 9, "timestamp": "2026-02-13T16:12:25.666992Z", "level": "info", "event": "Inputs parsed"}
# {"run_stem": "req_8f03ec1fc5__norag__llama3.3_latest", "base_stem": "req_8f03ec1fc5", "mode": "norag", "top_k": 6, "llm": "llama3.3:latest", "timestamp": "2026-02-13T16:12:25.666992Z", "level": "info", "event": "Run naming"}
# {"question_chars": 4941, "template_chars": 3863, "user_elements_lines": 9, "timestamp": "2026-02-13T16:12:25.667989Z", "level": "info", "event": "Prompt scaffold ready"}
# {"mode": "norag", "prompt_chars": 5989, "timestamp": "2026-02-13T16:12:25.667989Z", "level": "info", "event": "LLM start"}
# Schema validation: PASS (input.json)
# HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# {"mode": "norag", "timestamp": "2026-02-13T16:13:31.614030Z", "level": "info", "event": "LLM done"}
# {"mode": "norag", "output_chars": 6694, "timestamp": "2026-02-13T16:13:31.614537Z", "level": "info", "event": "DMP generation finished"}
# 100%|██████████| 1/1 [00:04<00:00,  4.42s/it]
#  Export files:
# markdown: C:\Users\Nahid\dmpchef\data\outputs\markdown\req_8f03ec1fc5__081331__norag__llama3.3_latest.md
# dmptool_json: C:\Users\Nahid\dmpchef\data\outputs\json\req_8f03ec1fc5__081331__norag__llama3.3_latest.dmptool.json
# docx: C:\Users\Nahid\dmpchef\data\outputs\docx\req_8f03ec1fc5__081331__norag__llama3.3_latest.docx
# pdf: C:\Users\Nahid\dmpchef\data\outputs\pdf\req_8f03ec1fc5__081331__norag__llama3.3_latest.pdf

# %%
# ----------------------------
# Run RAG 
# ----------------------------
from dmpchef.api import generate

# RAG:
result = generate(input_path, use_rag=True)

# Show export file paths only
print("\n Export files:")
for name, path in result["outputs"].items():
    print(f"{name}: {path}")
# Out:
# {"timestamp": "2026-02-13T16:13:37.066526Z", "level": "info", "event": "Config loaded successfully"}
# {"llm": "llama3.3:latest", "embed": "sentence-transformers/all-MiniLM-L6-v2", "hf_cache_dir": "data/cache/hf", "local_files_only": true, "allow_download_if_missing": true, "temperature": null, "num_predict": null, "num_ctx": null, "top_p": null, "top_k": null, "timestamp": "2026-02-13T16:13:37.068524Z", "level": "info", "event": "ModelLoader initialized"}
# {"llm": "llama3.3:latest", "rag_default": true, "data_pdfs": "data\\database", "index_dir": "data\\index", "debug_dir": "data\\outputs\\debug", "force_rebuild_index": false, "timestamp": "2026-02-13T16:13:37.076525Z", "level": "info", "event": "DMPPipeline initialized"}
# {"funding_agency": "NIH", "prompt_type": "nih_dmp", "template_md": "data\\inputs\\dmp-template.md", "retrieval_hint": "NIH Data Management and Sharing Plan (DMSP) guidance", "timestamp": "2026-02-13T16:13:37.078525Z", "level": "info", "event": "Funding agency selected"}
# {"mode": "rag", "use_rag_input": true, "rag_default": true, "use_rag_final": true, "timestamp": "2026-02-13T16:13:37.078525Z", "level": "info", "event": "Pipeline mode selected"}
# {"title_present": true, "title": "req_8f03ec1fc5", "input_fields": 9, "timestamp": "2026-02-13T16:13:37.078525Z", "level": "info", "event": "Inputs parsed"}
# {"run_stem": "req_8f03ec1fc5__rag__k6__llama3.3_latest", "base_stem": "req_8f03ec1fc5", "mode": "rag", "top_k": 6, "llm": "llama3.3:latest", "timestamp": "2026-02-13T16:13:37.079525Z", "level": "info", "event": "Run naming"}
# {"question_chars": 5103, "template_chars": 3863, "user_elements_lines": 9, "timestamp": "2026-02-13T16:13:37.079525Z", "level": "info", "event": "Prompt scaffold ready"}
# {"step": "ensure_rag_ready", "timestamp": "2026-02-13T16:13:37.079525Z", "level": "info", "event": "RAG phase start"}
# {"llm": "llama3.3:latest", "timestamp": "2026-02-13T16:13:37.080525Z", "level": "info", "event": "Loading embeddings for RAG"}
# Use pytorch device_name: cpu
# Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# Schema validation: PASS (input.json)
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1548.65it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# {"model": "sentence-transformers/all-MiniLM-L6-v2", "cache_dir": "C:\\Users\\Nahid\\dmpchef\\data\\cache\\hf", "local_files_only": true, "timestamp": "2026-02-13T16:13:37.286548Z", "level": "info", "event": "Embeddings loaded successfully"}
# {"timestamp": "2026-02-13T16:13:37.286548Z", "level": "info", "event": "Embeddings ready"}
# {"index_dir": "data\\index", "force_rebuild": false, "timestamp": "2026-02-13T16:13:37.287548Z", "level": "info", "event": "Preparing FAISS vectorstore"}
# {"path": "data\\index\\index.faiss", "timestamp": "2026-02-13T16:13:37.287548Z", "level": "info", "event": "Loading existing FAISS index"}
# {"search_type": "mmr", "top_k": 6, "fetch_k": 24, "lambda_mult": 0.5, "timestamp": "2026-02-13T16:13:37.293547Z", "level": "info", "event": "RAG retriever initialized"}
# {"step": "ensure_rag_ready", "timestamp": "2026-02-13T16:13:37.294548Z", "level": "info", "event": "RAG phase ready"}
# {"query_chars": 1038, "top_k": 6, "timestamp": "2026-02-13T16:13:37.294548Z", "level": "info", "event": "Retrieval start"}
# {"retrieved_docs": 6, "timestamp": "2026-02-13T16:13:37.327063Z", "level": "info", "event": "Retrieval raw done"}
# {"strategy": "first_fit", "selected_docs": 6, "approx_selected_chars": 5150, "max_ctx_chars": 12000, "timestamp": "2026-02-13T16:13:37.328063Z", "level": "info", "event": "Chunk selection"}
# {"retriever_top_k": 6, "retrieved_docs": 6, "retrieved_chars": 5472, "max_ctx_chars": 12000, "debug_context_file": "data\\outputs\\debug\\req_8f03ec1fc5__rag__k6__llama3.3_latest.retrieved_context.txt", "timestamp": "2026-02-13T16:13:37.329063Z", "level": "info", "event": "Retrieval complete"}
# {"mode": "rag", "prompt_chars": 11623, "timestamp": "2026-02-13T16:13:37.330063Z", "level": "info", "event": "LLM start"}
# HTTP Request: POST http://127.0.0.1:11434/api/generate "HTTP/1.1 200 OK"
# {"mode": "rag", "timestamp": "2026-02-13T16:14:32.247580Z", "level": "info", "event": "LLM done"}
# {"mode": "rag", "output_chars": 5055, "timestamp": "2026-02-13T16:14:32.248583Z", "level": "info", "event": "DMP generation finished"}
# 100%|██████████| 1/1 [00:02<00:00,  2.82s/it]
#  Export files:
# markdown: C:\Users\Nahid\dmpchef\data\outputs\markdown\req_8f03ec1fc5__081432__rag__k6__llama3.3_latest.md
# dmptool_json: C:\Users\Nahid\dmpchef\data\outputs\json\req_8f03ec1fc5__081432__rag__k6__llama3.3_latest.dmptool.json
# docx: C:\Users\Nahid\dmpchef\data\outputs\docx\req_8f03ec1fc5__081432__rag__k6__llama3.3_latest.docx
# pdf: C:\Users\Nahid\dmpchef\data\outputs\pdf\req_8f03ec1fc5__081432__rag__k6__llama3.3_latest.pdf
